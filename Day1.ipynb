# %%
import numpy as np
import pandas as pd

# %%
airport_data=pd.read_csv("../nyc-flights.csv")

# %%
A=list(airport_data.shape)

# %%
product=A[0]*A[1]
print(product)
# Out:
# 523760

# %%
airport_data.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      6   30       940         15      1216         -4      VX  N626VA
# 1  2013      5    7      1657         -3      2104         10      DL  N3760C
# 2  2013     12    8       859         -1      1238         11      DL  N712TW
# 3  2013      5   14      1841         -4      2122        -34      DL  N914DL
# 4  2013      7   21      1102         -3      1230         -8      9E  N823AY
#
#    flight origin dest  air_time  distance  hour  minute
# 0     407    JFK  LAX       313      2475     9      40
# 1     329    JFK  SJU       216      1598    16      57
# 2     422    JFK  LAX       376      2475     8      59
# 3    2391    JFK  TPA       135      1005    18      41
# 4    3652    LGA  ORF        50       296    11       2

# %%
df1 = airport_data.loc[(airport_data['origin']=='JFK') & (airport_data['dest']=='LAX')]
df1
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   30       940         15      1216         -4      VX
# 2      2013     12    8       859         -1      1238         11      DL
# 32     2013      7    5       920          5      1204         -6      AA
# 39     2013      8   22      1108         -7      1352        -12      UA
# 47     2013      3   27      1158         -2      1455        -16      DL
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32589  2013      1    4      1001         16      1232        -26      B6
# 32590  2013      7   20       717         17       941        -10      B6
# 32609  2013      6   21       934         -1      1205        -16      B6
# 32644  2013      9   30       939         19      1217         -3      VX
# 32712  2013      2    5      1340         -5      1704         -1      AA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
airport_data.groupby(['origin','dest']).agg({"air_time":[min,max]}).reset_index()
# Out:
#     origin dest air_time
#                      min  max
# 0      EWR  ALB       27   37
# 1      EWR  ANC      418  418
# 2      EWR  ATL       88  147
# 3      EWR  AUS      178  271
# 4      EWR  AVL       77  102
# ..     ...  ...      ...  ...
# 209    LGA  SYR       34   49
# 210    LGA  TPA      124  177
# 211    LGA  TVC       87   94
# 212    LGA  TYS       83  121
# 213    LGA  XNA      148  220
#
# [214 rows x 4 columns]

# %%
airport_data[(airport_data['origin']=='JFK') & (airport_data['dest']=='LAX') ]['flight']\
.value_counts()
# Out:
# 181     46
# 21      43
# 399     41
# 19      40
# 1       39
#         ..
# 712      1
# 1159     1
# 2344     1
# 274      1
# 631      1
# Name: flight, Length: 76, dtype: int64

# %%
airport_data['dest'].unique()
# Out:
# array(['JFK', 'LGA', 'EWR'], dtype=object)

# %%
airport_data['dest'].value_counts()
# Out:
# ATL    1653
# ORD    1588
# LAX    1583
# BOS    1470
# CLT    1383
#        ...
# BZN       2
# JAC       2
# EYW       1
# ANC       1
# CHO       1
# Name: dest, Length: 102, dtype: int64

# %%
airport_data.shape
# Out:
# (32735, 16)

# %%
airport_data['dest'].describe()
# Out:
# count     32735
# unique      102
# top         ATL
# freq       1653
# Name: dest, dtype: object

# %%
df1.loc[df1.groupby(['year']).dep_time.idxmin()]
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 14427  2013      7   22         7         82       338        123      B6
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# 14427  N646JB     623    JFK  LAX       317      2475     0       7

# %%
airport_data['year'].nunique()
# Out:
# 1

# %%
airport_data.year
# Out:
# 0        2013
# 1        2013
# 2        2013
# 3        2013
# 4        2013
#          ...
# 32730    2013
# 32731    2013
# 32732    2013
# 32733    2013
# 32734    2013
# Name: year, Length: 32735, dtype: int64

# %%
airport_data.iloc[0]
# Out:
# year           2013
# month             6
# day              30
# dep_time        940
# dep_delay        15
# arr_time       1216
# arr_delay        -4
# carrier          VX
# tailnum      N626VA
# flight          407
# origin          JFK
# dest            LAX
# air_time        313
# distance       2475
# hour              9
# minute           40
# Name: 0, dtype: object

# %%
airport_data.iloc[:4,5]
# Out:
# 0    1216
# 1    2104
# 2    1238
# 3    2122
# Name: arr_time, dtype: int64

# %%
airport_data.iloc[-3:,0]
# Out:
# 32732    2013
# 32733    2013
# 32734    2013
# Name: year, dtype: int64

# %%
airport_data.loc[:8,['carrier','air_time','distance','hour']]
# Out:
#   carrier  air_time  distance  hour
# 0      VX       313      2475     9
# 1      DL       216      1598    16
# 2      DL       376      2475     8
# 3      DL       135      1005    18
# 4      9E        50       296    11
# 5      AA       138       733    18
# 6      WN       240      1411    12
# 7      B6        48       228    19
# 8      AA       148      1096     7

# %%
airport_data.loc[airport_data.month==5]
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 1      2013      5    7      1657         -3      2104         10      DL
# 3      2013      5   14      1841         -4      2122        -34      DL
# 36     2013      5   13      1825         -4      2000        -35      DL
# 63     2013      5   26      1417         -8      1529        -21      B6
# 67     2013      5   25      1610         -5      1827        -13      MQ
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32648  2013      5   15      1723         73      1833         42      9E
# 32666  2013      5   13       603         -1       801        -52      UA
# 32683  2013      5    1       621         -9       816        -57      US
# 32691  2013      5   17      1941        -14      2134         -5      EV
# 32693  2013      5   28       553         -7       750         -5      EV
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
airport_data.loc[(airport_data.month==5) & (airport_data.hour>=10)]
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 1      2013      5    7      1657         -3      2104         10      DL
# 3      2013      5   14      1841         -4      2122        -34      DL
# 36     2013      5   13      1825         -4      2000        -35      DL
# 63     2013      5   26      1417         -8      1529        -21      B6
# 67     2013      5   25      1610         -5      1827        -13      MQ
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32597  2013      5    2      2050          5      2311         -2      EV
# 32610  2013      5   21      1131          0      1458         13      DL
# 32635  2013      5   11      1323          3      1541        -43      UA
# 32648  2013      5   15      1723         73      1833         42      9E
# 32691  2013      5   17      1941        -14      2134         -5      EV
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
airport_data.loc[(airport_data.month.isin([5,6]))]
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   30       940         15      1216         -4      VX
# 1      2013      5    7      1657         -3      2104         10      DL
# 3      2013      5   14      1841         -4      2122        -34      DL
# 10     2013      6   17       940          5      1050         -4      B6
# 28     2013      6    8      1839         -1      2120        -12      DL
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32683  2013      5    1       621         -9       816        -57      US
# 32691  2013      5   17      1941        -14      2134         -5      EV
# 32693  2013      5   28       553         -7       750         -5      EV
# 32694  2013      6    1      2100         20      2213         13      MQ
# 32700  2013      6    3      1420         22      1804         49      DL
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
airport_data
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   30       940         15      1216         -4      VX
# 1      2013      5    7      1657         -3      2104         10      DL
# 2      2013     12    8       859         -1      1238         11      DL
# 3      2013      5   14      1841         -4      2122        -34      DL
# 4      2013      7   21      1102         -3      1230         -8      9E
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32730  2013     10    8       752         -8       921        -28      9E
# 32731  2013      7    7       812         -3      1043          8      DL
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
airport_data.loc[airport_data.arr_delay.notnull()]
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   30       940         15      1216         -4      VX
# 1      2013      5    7      1657         -3      2104         10      DL
# 2      2013     12    8       859         -1      1238         11      DL
# 3      2013      5   14      1841         -4      2122        -34      DL
# 4      2013      7   21      1102         -3      1230         -8      9E
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32730  2013     10    8       752         -8       921        -28      9E
# 32731  2013      7    7       812         -3      1043          8      DL
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
airport_data['year']=2013
airport_data['year']
# Out:
# 0        2013
# 1        2013
# 2        2013
# 3        2013
# 4        2013
#          ...
# 32730    2013
# 32731    2013
# 32732    2013
# 32733    2013
# 32734    2013
# Name: year, Length: 32735, dtype: int64

# %%
#summary function and map
airport_data.month.describe()
# Out:
# count    32735.000000
# mean         6.576081
# std          3.413269
# min          1.000000
# 25%          4.000000
# 50%          7.000000
# 75%         10.000000
# max         12.000000
# Name: month, dtype: float64

# %%
airport_data.month.mean()
# Out:
# 6.576080647624867

# %%
airport_data.day.describe()
# Out:
# count    32735.000000
# mean        15.777241
# std          8.793983
# min          1.000000
# 25%          8.000000
# 50%         16.000000
# 75%         23.000000
# max         31.000000
# Name: day, dtype: float64

# %%
airport_data
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   30       940         15      1216         -4      VX
# 1      2013      5    7      1657         -3      2104         10      DL
# 2      2013     12    8       859         -1      1238         11      DL
# 3      2013      5   14      1841         -4      2122        -34      DL
# 4      2013      7   21      1102         -3      1230         -8      9E
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32730  2013     10    8       752         -8       921        -28      9E
# 32731  2013      7    7       812         -3      1043          8      DL
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
airport_data.arr_time.unique()
# Out:
# array([1216, 2104, 1238, ...,  204,  231,  605])

# %%
airport_data.arr_time.value_counts()
# Out:
# 1727    57
# 1215    56
# 1018    55
# 1045    54
# 1035    54
#         ..
# 242      1
# 223      1
# 218      1
# 234      1
# 204      1
# Name: arr_time, Length: 1302, dtype: int64

# %%
airport_data.arr_time.mean()
# Out:
# 1502.9074079731174

# %%
mean_time=airport_data.arr_time.mean()
airport_data.arr_time.map(lambda p:  mean_time-p)
# Out:
# 0        286.907408
# 1       -601.092592
# 2        264.907408
# 3       -619.092592
# 4        272.907408
#             ...
# 32730    581.907408
# 32731    459.907408
# 32732    183.907408
# 32733    457.907408
# 32734   -439.092592
# Name: arr_time, Length: 32735, dtype: float64

# %%
airport_data
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   30       940         15      1216         -4      VX
# 1      2013      5    7      1657         -3      2104         10      DL
# 2      2013     12    8       859         -1      1238         11      DL
# 3      2013      5   14      1841         -4      2122        -34      DL
# 4      2013      7   21      1102         -3      1230         -8      9E
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32730  2013     10    8       752         -8       921        -28      9E
# 32731  2013      7    7       812         -3      1043          8      DL
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
airport_data.groupby(['day','month']).dep_time.min()
# Out:
# day  month
# 1    1        606
#      2        527
#      3        505
#      4        555
#      5        548
#              ...
# 31   5        544
#      7        542
#      8        549
#      10       552
#      12        18
# Name: dep_time, Length: 365, dtype: int64

# %%
airport_data.groupby(['day','distance']).distance.min()
# Out:
# day  distance
# 1    94            94
#      96            96
#      116          116
#      143          143
#      160          160
#                  ...
# 31   2475        2475
#      2565        2565
#      2576        2576
#      2586        2586
#      4983        4983
# Name: distance, Length: 4933, dtype: int64

# %%
airport_data.groupby(['day']).air_time.agg([len,max,min])
# Out:
#       len  max  min
# day
# 1    1101  589   25
# 2    1060  637   27
# 3    1107  585   25
# 4    1073  649   26
# 5    1024  654   25
# 6    1055  611   24
# 7    1052  643   27
# 8    1002  601   23
# 9    1057  640   23
# 10   1046  667   24
# 11   1122  637   22
# 12   1031  620   27
# 13   1111  614   22
# 14   1086  388   24
# 15   1151  686   23
# 16   1034  638   24
# 17   1095  609   22
# 18   1074  654   26
# 19   1101  616   25
# 20   1067  659   26
# 21   1105  642   22
# 22   1111  648   23
# 23   1058  655   22
# 24   1093  393   24
# 25   1045  634   27
# 26   1072  629   23
# 27   1109  632   23
# 28   1030  614   25
# 29   1045  626   26
# 30   1001  368   24
# 31    617  655   26

# %%
airport_data
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   30       940         15      1216         -4      VX
# 1      2013      5    7      1657         -3      2104         10      DL
# 2      2013     12    8       859         -1      1238         11      DL
# 3      2013      5   14      1841         -4      2122        -34      DL
# 4      2013      7   21      1102         -3      1230         -8      9E
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32730  2013     10    8       752         -8       921        -28      9E
# 32731  2013      7    7       812         -3      1043          8      DL
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
airport_data.loc[:,'flight'].sum()
# Out:
# 63761121

# %%
airport_data.loc[:,'flight'].count()
# Out:
# 32735

# %%
A=airport_data.loc[:,'flight'].unique()
len(A)
# Out:
# 2951

# %%
airport_data.loc[:,'flight'].describe()
# Out:
# count    32735.000000
# mean      1947.796579
# std       1621.204308
# min          1.000000
# 25%        550.000000
# 50%       1473.000000
# 75%       3416.000000
# max       6181.000000
# Name: flight, dtype: float64

# %%
airport_data.groupby(['day','distance','hour']).hour.max()
# Out:
# day  distance  hour
# 1    94        8        8
#                9        9
#                15      15
#                16      16
#                19      19
#                        ..
# 31   2586      16      16
#                17      17
#                18      18
#                20      20
#      4983      9        9
# Name: hour, Length: 22447, dtype: int64

# %%
df=airport_data.groupby(['carrier','origin','tailnum','distance','hour','year','month','day','air_time'])

# %%
df.flight.sum()
# Out:
# carrier  origin  tailnum  distance  hour  year  month  day  air_time
# 9E       EWR     N162PQ   488       15    2013  1      25   84          3694
#                  N181PQ   488       12    2013  1      11   92          3694
#                  N292PQ   1008      6     2013  12     9    166         4270
#                                                        16   153         4270
#                  N295PQ   1008      11    2013  12     12   165         3312
#                                                                         ...
# YV       LGA     N934FJ   544       20    2013  5      19   77          2751
#                  N935LR   544       14    2013  7      1    85          2807
#                  N938LR   544       11    2013  8      16   93          2729
#                  N939LR   544       17    2013  7      26   78          2751
#                  N942LR   544       11    2013  12     4    91          2885
# Name: flight, Length: 32735, dtype: int64

# %%
airport_data.loc[:0,['distance','year']]
# Out:
#    distance  year
# 0      2475  2013

# %%
review=airport_data.loc[(airport_data.day==1) & (airport_data.flight>=353)]
review
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 5      2013      1    1      1817         -3      2008          3      AA
# 22     2013      2    1       729          9      1018         -5      UA
# 30     2013     11    1      1058         -2      1227        -23      WN
# 55     2013      7    1      2007         82      2123         53      AA
# 80     2013      1    1      1454         -4      1554        -21      EV
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32544  2013      4    1      2052         82      2304         93      EV
# 32546  2013      4    1      1126         38      1401         60      EV
# 32552  2013      9    1       804          9      1138        -16      UA
# 32656  2013     11    1      1254         -6      1359        -11      US
# 32694  2013      6    1      2100         20      2213         13      MQ
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
review.reset_index()
# Out:
#      index  year  month  day  dep_time  dep_delay  arr_time  arr_delay  \
# 0        5  2013      1    1      1817         -3      2008          3
# 1       22  2013      2    1       729          9      1018         -5
# 2       30  2013     11    1      1058         -2      1227        -23
# 3       55  2013      7    1      2007         82      2123         53
# 4       80  2013      1    1      1454         -4      1554        -21
# ..     ...   ...    ...  ...       ...        ...       ...        ...
# 896  32544  2013      4    1      2052         82      2304         93
# 897  32546  2013      4    1      1126         38      1401         60
# 898  32552  2013      9    1       804          9      1138        -16
# 899  32656  2013     11    1      1254         -6      1359        -11
# 900  32694  2013      6    1      2100         20      2213         13
#
#     carrier tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
review
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 5      2013      1    1      1817         -3      2008          3      AA
# 22     2013      2    1       729          9      1018         -5      UA
# 30     2013     11    1      1058         -2      1227        -23      WN
# 55     2013      7    1      2007         82      2123         53      AA
# 80     2013      1    1      1454         -4      1554        -21      EV
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32544  2013      4    1      2052         82      2304         93      EV
# 32546  2013      4    1      1126         38      1401         60      EV
# 32552  2013      9    1       804          9      1138        -16      UA
# 32656  2013     11    1      1254         -6      1359        -11      US
# 32694  2013      6    1      2100         20      2213         13      MQ
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
review.sort_values(by='flight')
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 5      2013      1    1      1817         -3      2008          3      AA
# 18327  2013      8    1      1004          1      1216         41      FL
# 20371  2013      7    1      1034         31      1239         64      FL
# 6622   2013     12    1      1259         -1      1520         -4      DL
# 28411  2013     10    1       952         -8      1106        -25      FL
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 20478  2013      7    1      1713        133      1858        129      EV
# 2866   2013     11    1      1930         19      2128         18      EV
# 14922  2013     12    1      2028         -1      2156        -20      EV
# 8670   2013     10    1      1435         -5      1547        -13      EV
# 25909  2013     10    1       606         -4       719         -5      EV
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
review.sort_index()
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 5      2013      1    1      1817         -3      2008          3      AA
# 22     2013      2    1       729          9      1018         -5      UA
# 30     2013     11    1      1058         -2      1227        -23      WN
# 55     2013      7    1      2007         82      2123         53      AA
# 80     2013      1    1      1454         -4      1554        -21      EV
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32544  2013      4    1      2052         82      2304         93      EV
# 32546  2013      4    1      1126         38      1401         60      EV
# 32552  2013      9    1       804          9      1138        -16      UA
# 32656  2013     11    1      1254         -6      1359        -11      US
# 32694  2013      6    1      2100         20      2213         13      MQ
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
airport_data.sort_values(by=['month','arr_time','dep_delay','arr_delay'])
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 6909   2013      1   16      2018         -7         1         32      UA
# 28925  2013      1   15      2304         19         1          4      B6
# 2303   2013      1    6      2101          1         2         19      B6
# 18106  2013      1   16      2136         50         3         45      EV
# 5874   2013      1    4      2114         -1         4          7      B6
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 16896  2013     12   10      2020          0      2359          4      UA
# 26838  2013     12    9      2127         32      2359         27      B6
# 21889  2013     12   18      2108         50      2359         46      B6
# 12580  2013     12   21      2244         -1      2400         -3      B6
# 22945  2013     12    5      2258         29      2400         17      B6
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
airport_data.rename(index ={0:0,1:1})
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013      6   30       940         15      1216         -4      VX
# 1      2013      5    7      1657         -3      2104         10      DL
# 2      2013     12    8       859         -1      1238         11      DL
# 3      2013      5   14      1841         -4      2122        -34      DL
# 4      2013      7   21      1102         -3      1230         -8      9E
# ...     ...    ...  ...       ...        ...       ...        ...     ...
# 32730  2013     10    8       752         -8       921        -28      9E
# 32731  2013      7    7       812         -3      1043          8      DL
# 32732  2013      9    3      1057         -1      1319        -19      UA
# 32733  2013     10   15       844         56      1045         60      B6
# 32734  2013      3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
airport_data.rename(columns={'year':'yr','month':'mnth'})
# Out:
#          yr  mnth  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0      2013     6   30       940         15      1216         -4      VX
# 1      2013     5    7      1657         -3      2104         10      DL
# 2      2013    12    8       859         -1      1238         11      DL
# 3      2013     5   14      1841         -4      2122        -34      DL
# 4      2013     7   21      1102         -3      1230         -8      9E
# ...     ...   ...  ...       ...        ...       ...        ...     ...
# 32730  2013    10    8       752         -8       921        -28      9E
# 32731  2013     7    7       812         -3      1043          8      DL
# 32732  2013     9    3      1057         -1      1319        -19      UA
# 32733  2013    10   15       844         56      1045         60      B6
# 32734  2013     3   28      1813         -3      1942        -23      UA
#
#       tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
carr_list = ["VX",'DL','9E','UA']
airport_data[airport_data["carrier"].isin(carr_list)][["flight","origin"]]
# Out:
#        flight origin
# 0         407    JFK
# 1         329    JFK
# 2         422    JFK
# 3        2391    JFK
# 4        3652    LGA
# ...       ...    ...
# 32728    3525    JFK
# 32730    3611    JFK
# 32731    1429    JFK
# 32732    1545    EWR
# 32734    1053    EWR
#
# [12714 rows x 2 columns]

# %%
airport_data.groupby(["year",'origin','dest',"flight"]).size().reset_index(name = "count")
# Out:
#       year origin dest  flight  count
# 0     2013    EWR  ALB    3811      2
# 1     2013    EWR  ALB    4088      6
# 2     2013    EWR  ALB    4093      1
# 3     2013    EWR  ALB    4117      2
# 4     2013    EWR  ALB    4120      1
# ...    ...    ...  ...     ...    ...
# 5672  2013    LGA  XNA    3553      3
# 5673  2013    LGA  XNA    3713      4
# 5674  2013    LGA  XNA    4413     11
# 5675  2013    LGA  XNA    4525      8
# 5676  2013    LGA  XNA    4534     13
#
# [5677 rows x 5 columns]
