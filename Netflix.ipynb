# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
ntf=pd.read_csv('Netflix Dataset.csv')

# %%
ntf.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# ...

# %%
ntf.shape
# Out:
# (7789, 11)

# %% [markdown]
# # Null Values

# %%
ntf.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
ntf['Country'].fillna('Netflix Country',inplace=True)

# %%
ntf['Director'].fillna('Netflix Director',inplace=True)

# %%
ntf['Cast'].fillna('Netflix Cast',inplace=True)

# %% [markdown]
# # Heat map application .
# It is one of the library of seaborn

# %%
sns.heatmap(ntf.isna())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/gg/rkgw68311276r9cdpgzyzhlh0000gn/T/ipykernel_45777/3672616372.py in <module>
# ----> 1 sns.heatmap(ntf.isna())
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     551     if square:
#     552         ax.set_aspect("equal")
# --> 553     plotter.plot(ax, cbar_ax, kwargs)
#     554     return ax
#     555
#
# ...

# %% [markdown]
# # Checking dataset

# %%
ntf.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%   Netflix Director
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# ...

# %%
ntf[(ntf['Director']=='Netflix Director')]
# Out:
#      Show_Id Category                                Title          Director  \
# 0         s1  TV Show                                   3%  Netflix Director
# 11       s12  TV Show                                 1983  Netflix Director
# 16       s17  TV Show                               Feb-09  Netflix Director
# 19       s20    Movie                                  '89  Netflix Director
# 24       s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac  Netflix Director
# ...      ...      ...                                  ...               ...
# 7777   s7776  TV Show                           Zoids Wild  Netflix Director
# 7779   s7778  TV Show                          Zombie Dumb  Netflix Director
# 7781   s7780  TV Show                            Zona Rosa  Netflix Director
# 7786   s7785    Movie                    Zulu Man in Japan  Netflix Director
# 7787   s7786  TV Show                Zumbo's Just Desserts  Netflix Director
#
# ...

# %%
ntf[ntf['Cast'].str.contains('Bryson Baugus','Emily Neves')].describe()
# Out:
#        Show_Id Category                                Title  \
# count        1        1                                    1
# unique       1        1                                    1
# top        s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac
# freq         1        1                                    1
#
#                 Director                                               Cast  \
# count                  1                                                  1
# unique                 1                                                  1
# top     Netflix Director  Bryson Baugus, Emily Neves, Blake Shepard, Pat...
# freq                   1                                                  1
#
#        Country      Release_Date Rating   Duration  \
# count        1                 1      1          1
# unique       1                 1      1          1
# top      Japan  January 23, 2020  TV-14  2 Seasons
# freq         1                 1      1          1
#
# ...

# %%
ntf.columns  #To see columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
#Duplicate values
ntf[ntf.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
#Removing Duplicate Values
ntf.drop_duplicates(inplace=True)

# %%
#for House of Cards who is the director and show id.
ntf[(ntf['Title']=='House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
ntf[(ntf['Title']=='House of Cards')]['Director']
# Out:
# 2832    Robin Wright, David Fincher, Gerald McRaney, J...
# Name: Director, dtype: object

# %%
ntf[ntf['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
ntf[ntf['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
ntf['Category'].value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# # to_datetime()

# %%
ntf['Date_N']=pd.to_datetime(ntf['Release_Date'])

# %%
ntf.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%   Netflix Director
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
ntf.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%   Netflix Director
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# # .dt.year.value_counts()
# It gives year from year/month/date format.

# %%
ntf['Date_N'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
ntf['Date_N'].value_counts()
# Out:
# 2020-01-01    119
# 2019-11-01     96
# 2018-03-01     76
# 2019-12-31     76
# 2018-10-01     72
#              ...
# 2017-03-28      1
# 2020-05-05      1
# 2017-09-19      1
# 2017-08-16      1
# 2020-01-11      1
# Name: Date_N, Length: 1512, dtype: int64

# %%
ntf['Date_N']
# Out:
# 0      2020-08-14
# 1      2016-12-23
# 2      2018-12-20
# 3      2017-11-16
# 4      2020-01-01
#           ...
# 7784   2020-10-19
# 7785   2019-03-02
# 7786   2020-09-25
# 7787   2020-10-31
# 7788   2020-03-01
# Name: Date_N, Length: 7787, dtype: datetime64[ns]

# %%
ntf.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%   Netflix Director
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_N    year  \
# ...

# %%
new_dta=ntf.drop(columns=['Show_Id','Director','Category','Title','Cast','Release_Date','Rating','Duration','Type','Description','Date_N','year','unit'],axis=1).set_index('Country')

# %%
new_dta
# Out:
#                                                    minutes
# Country
# Brazil                                                   4
# Mexico                                                  93
# Singapore                                               78
# United States                                           80
# United States                                          123
# ...                                                    ...
# Sweden, Czech Republic, United Kingdom, Denmark...      99
# India                                                  111
# Netflix Country                                         44
# Australia                                                1
# United Kingdom, Canada, United States                   90
#
# [7787 rows x 1 columns]

# %%
sns.heatmap(new_dta)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/gg/rkgw68311276r9cdpgzyzhlh0000gn/T/ipykernel_45777/2515454495.py in <module>
# ----> 1 sns.heatmap(new_dta)
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     551     if square:
#     552         ax.set_aspect("equal")
# --> 553     plotter.plot(ax, cbar_ax, kwargs)
#     554     return ax
#     555
#
# ...

# %%
dta=ntf[(ntf['Category']=='TV Show')][['year','minutes']].set_index('year')
# dta['minutes'].isnull().value_counts()
# # dta[''].fillna()
dta
# Out:
#        minutes
# year
# 2020.0       4
# 2017.0       1
# 2018.0       1
# 2019.0       1
# 2019.0       1
# ...        ...
# 2016.0       1
# 2020.0       1
# 2019.0       2
# 2019.0       1
# 2020.0       1
#
# [2410 rows x 1 columns]

# %%
sns.heatmap(dta)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/gg/rkgw68311276r9cdpgzyzhlh0000gn/T/ipykernel_45777/2068867765.py in <module>
# ----> 1 sns.heatmap(dta)
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     551     if square:
#     552         ax.set_aspect("equal")
# --> 553     plotter.plot(ax, cbar_ax, kwargs)
#     554     return ax
#     555
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# nntf=ntf['Date_N'].dt.year.value_counts()
sns.set(style='darkgrid')
plt.figure(figsize=(20,10))
sns.countplot(x='minutes',data=dta,palette='Spectral')
plt.title('Year Category Progress')
# Out:
# Text(0.5, 1.0, 'Year Category Progress')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     251
#     252     if 'png' in formats:
# --> 253         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     254     if 'retina' in formats or 'png2x' in formats:
#     255         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %%
ntf[(ntf['Category']=='TV Show')]['Category'].count()
# Out:
# 2410

# %% [markdown]
# # How many movies and tv shows are in the data set. Also show in bar graph

# %%
ntf[(ntf['Category']=='TV Show')]['Category'].value_counts()
# Out:
# TV Show    2410
# Name: Category, dtype: int64

# %%
ntf['Category'].isnull().sum()
# Out:
# 0

# %%
movies=0
tvshow=0
for i in ntf['Category']:
    if(i=='Movie'):
        movies +=1
    else:
        tvshow +=1
print('movies:{},\ntvshow:{}'.format(movies,tvshow))
# Out:
# movies:5377,
# tvshow:2410

# %%
sns.heatmap(ntf.isnull())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/gg/rkgw68311276r9cdpgzyzhlh0000gn/T/ipykernel_45777/69804041.py in <module>
# ----> 1 sns.heatmap(ntf.isnull())
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     551     if square:
#     552         ax.set_aspect("equal")
# --> 553     plotter.plot(ax, cbar_ax, kwargs)
#     554     return ax
#     555
#
# ...

# %%
ntf.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%   Netflix Director
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
ntf.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%   Netflix Director
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
sns.countplot(ntf['year'])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='year', ylabel='count'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     251
#     252     if 'png' in formats:
# ...

# %%
ntf.groupby(['Category']).Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# # countplot() use
# it is seaborn library

# %%
sns.countplot((ntf['Category']=='TV Show'))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Category', ylabel='count'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     251
# ...

# %% [markdown]
# Show all movies that were released in 2000.

# %%
ntf['year']=ntf['Date_N'].dt.year

# %%
ntf.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%   Netflix Director
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_N    year  \
# ...

# %%
ntf[(ntf['year']==2000) & (ntf['Category']=='Movie')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, year, minutes, unit]
# Index: []

# %%
ntf[(ntf['Category']=='Movie') & (ntf['year']==2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, year, minutes, unit]
# Index: []

# %% [markdown]
# # All tv shows released in India.

# %%
ntf[(ntf['Category']=='TV Show') & (ntf['Country']=='India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# # Top 10 directors who gave highest number of tv shows and movies.

# %%
ntf['Director'].value_counts().head(10)
# Out:
# Netflix Director          2388
# Raúl Campos, Jan Suter      18
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Martin Scorsese             12
# Youssef Chahine             12
# Jay Chapman                 12
# Steven Spielberg            10
# David Dhawan                 9
# Name: Director, dtype: int64

# %%
ntf[(ntf['Category']=='Movie') & (ntf['Type']=='Comedy') | (ntf['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title           Director  \
# 19       s20    Movie                     '89   Netflix Director
# 58       s59  TV Show             100% Hotter   Netflix Director
# 82       s83    Movie     2036 Origin Unknown      Hasraf Dulull
# 85       s86  TV Show                21 Again   Netflix Director
# 93       s94    Movie       27: Gone Too Soon  Simon Napier-Bell
# ...      ...      ...                     ...                ...
# 7670   s7669  TV Show  World War II in Colour   Netflix Director
# 7671   s7670  TV Show  World's Busiest Cities   Netflix Director
# 7688   s7687    Movie  XV: Beyond the Tryline   Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu        James Brown
# 7740   s7739  TV Show         Young Wallander   Netflix Director
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# # In how many movies/show tom cruise cast.
# In it we will use str.contains()

# %%
ntf[ntf['Cast'].str.contains('Tom Cruise')]['Category'].value_counts()
# Out:
# Movie    2
# Name: Category, dtype: int64

# %% [markdown]
# # Different Ratings defined by Netflix

# %%
ntf['Rating'].value_counts()
# Out:
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: Rating, dtype: int64

# %%
ntf['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# How many movies got 'TV-14 rating' in canada

# %%
ntf[ (ntf['Category']=='Movie')&(ntf['Rating']=='TV-14') & (ntf['Country']=='Canada')].count()
# Out:
# Show_Id         11
# Category        11
# Title           11
# Director        11
# Cast            11
# Country         11
# Release_Date    11
# Rating          11
# Duration        11
# Type            11
# Description     11
# Date_N          11
# year            11
# minutes         11
# unit            11
# dtype: int64

# %%
ntf[(ntf['Category']=='Movie')&(ntf['Rating']=='TV-14') & (ntf['Country']=='Canada')].shape
# Out:
# (11, 15)

# %% [markdown]
# how many tv shows got R rating after 2018

# %%
ntf[(ntf['Category']=='TV Show')&(ntf['Rating']=='R')&(ntf['year']>2018)].shape
# Out:
# (1, 13)

# %% [markdown]
# What is th maximum duration of tv shows/movies on netflix.

# %%
ntf.groupby('Category').agg({'Duration':[max,min]})
# Out:
#            Duration
#                 max       min
# Category
# Movie        99 min    10 min
# TV Show   9 Seasons  1 Season

# %%
ntf.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%   Netflix Director
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
ntf[['minutes','unit']]=ntf['Duration'].str.split(' ',expand=True)

# %%
ntf.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%   Netflix Director
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# ...

# %%
ntf.groupby('Category').agg({'minutes':[max,min]})
# Out:
#          minutes
#              max min
# Category
# Movie         99  10
# TV Show        9   1

# %%
ntf['minutes'].max()
# Out:
# '99'

# %% [markdown]
# Which country has highest number of tv shows

# %%
ntf[(ntf['Category']=='TV Show')]['Country'].value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# Sorting dataset by year.

# %%
ntf.sort_values(by=['year'])
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five      Netflix Director
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki      Netflix Director
# 3492   s3493  TV Show           La Familia P. Luche      Netflix Director
# 3946   s3947  TV Show                         Maron      Netflix Director
# 5138   s5138  TV Show                  Red vs. Blue      Netflix Director
# 6066   s6066  TV Show  The Adventures of Figaro Pho      Netflix Director
#
#                                                    Cast          Country  \
# ...

# %% [markdown]
# find all the instances where:
# 1.Category is 'Movie' and type is 'Drama
# or
# 2.Category is 'TV Show' and Type is 'Kids TV'.

# %%
ntf[(ntf['Category']=='Movie') & (ntf['Type']=='Dramas')].head()
# Out:
#     Show_Id Category                       Title        Director  \
# 4        s5    Movie                          21  Robert Luketic
# 7        s8    Movie                         187  Kevin Reynolds
# 170    s171    Movie                A Family Man   Mark Williams
# 232    s233    Movie  A Stoning in Fulham County   Larry Elikann
# 295    s296    Movie          Across Grace Alley   Ralph Macchio
#
#                                                   Cast                Country  \
# 4    Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...          United States
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...          United States
# 170  Gerard Butler, Gretchen Mol, Alison Brie, Will...  Canada, United States
# 232  Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...          United States
# 295  Ben Hyland, Marsha Mason, Karina Smirnoff, Col...          United States
#
#           Release_Date Rating Duration    Type  \
# 4      January 1, 2020  PG-13  123 min  Dramas
# ...

# %%
ntf[(ntf['Category']=='TV Show') & (ntf['Type']=="Kids' TV")].head()
# Out:
#     Show_Id Category              Title             Director  \
# 111    s112  TV Show            44 Cats     Netflix Director
# 276    s277  TV Show       Abby Hatcher          Kyran Kelly
# 434    s435  TV Show        Alphablocks     Netflix Director
# 598    s599  TV Show  Ask the StoryBots     Netflix Director
# 706    s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
#
#                                                   Cast                Country  \
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
# 434    Teresa Gallagher, David Holt, Lizzie Waterworth         United Kingdom
# 598  Judy Greer, Erin Fitzgerald, Fred Tatasciore, ...          United States
# 706             Meghna Erande Joshi, Parminder Ghumman        Netflix Country
#
#         Release_Date Rating   Duration      Type  \
# 111  October 1, 2020  TV-Y7  2 Seasons  Kids' TV
# ...

# %%
ntf[((ntf['Category']=='Movie') & (ntf['Type']=='Dramas')) |((ntf['Category']=='TV Show') & (ntf['Type']=="Kids' TV")) ]
# Out:
#      Show_Id Category                       Title          Director  \
# 4         s5    Movie                          21    Robert Luketic
# 7         s8    Movie                         187    Kevin Reynolds
# 111     s112  TV Show                     44 Cats  Netflix Director
# 170     s171    Movie                A Family Man     Mark Williams
# 232     s233    Movie  A Stoning in Fulham County     Larry Elikann
# ...      ...      ...                         ...               ...
# 7668   s7667  TV Show               World of Winx    Iginio Straffi
# 7717   s7716  TV Show                        Yoko  Netflix Director
# 7719   s7718  TV Show                         YOM  Netflix Director
# 7758   s7757  TV Show                          Z4  Netflix Director
# 7761   s7760  TV Show                   Zak Storm  Netflix Director
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
