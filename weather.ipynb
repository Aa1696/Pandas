# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Reading csv files

# %%
wt=pd.read_csv('Weather-Data.csv')

# %% [markdown]
# # Basic Pandas command
# .head()
# .shape()
# .groupby()
# .tail()
# .filter()
# .describe()
# .agg()
# .sort_values()
# .sort_index()
# .nunique()
# .values_count()

# %%
wt.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
sns.countplot(wt['Visibility_km'])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Visibility_km', ylabel='count'>

# %%
wt.shape
# Out:
# (8784, 8)

# %%
wt.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
sns.heatmap(wt.isnull())
# Out:
# <AxesSubplot:>

# %%
wt.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
wt.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
wt['Date/Time'].nunique()
# Out:
# 8784

# %%
wt['Date/Time'].unique()
# Out:
# array(['1/1/2012 0:00', '1/1/2012 1:00', '1/1/2012 2:00', ...,
#        '12/31/2012 21:00', '12/31/2012 22:00', '12/31/2012 23:00'],
#       dtype=object)

# %%
dt={}
for i in wt['Date/Time']:
    if(i not in dt):
        dt[i]=0
    else:
        dt[i] +=1
print(dt)
# Out:
# {'1/1/2012 0:00': 0, '1/1/2012 1:00': 0, '1/1/2012 2:00': 0, '1/1/2012 3:00': 0, '1/1/2012 4:00': 0, '1/1/2012 5:00': 0, '1/1/2012 6:00': 0, '1/1/2012 7:00': 0, '1/1/2012 8:00': 0, '1/1/2012 9:00': 0, '1/1/2012 10:00': 0, '1/1/2012 11:00': 0, '1/1/2012 12:00': 0, '1/1/2012 13:00': 0, '1/1/2012 14:00': 0, '1/1/2012 15:00': 0, '1/1/2012 16:00': 0, '1/1/2012 17:00': 0, '1/1/2012 18:00': 0, '1/1/2012 19:00': 0, '1/1/2012 20:00': 0, '1/1/2012 21:00': 0, '1/1/2012 22:00': 0, '1/1/2012 23:00': 0, '1/2/2012 0:00': 0, '1/2/2012 1:00': 0, '1/2/2012 2:00': 0, '1/2/2012 3:00': 0, '1/2/2012 4:00': 0, '1/2/2012 5:00': 0, '1/2/2012 6:00': 0, '1/2/2012 7:00': 0, '1/2/2012 8:00': 0, '1/2/2012 9:00': 0, '1/2/2012 10:00': 0, '1/2/2012 11:00': 0, '1/2/2012 12:00': 0, '1/2/2012 13:00': 0, '1/2/2012 14:00': 0, '1/2/2012 15:00': 0, '1/2/2012 16:00': 0, '1/2/2012 17:00': 0, '1/2/2012 18:00': 0, '1/2/2012 19:00': 0, '1/2/2012 20:00': 0, '1/2/2012 21:00': 0, '1/2/2012 22:00': 0, '1/2/2012 23:00': 0, '1/3/2012
# ...

# %%
wt[(wt['Wind Speed_km/h'])==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
wt[(wt['Wind Speed_km/h'])==4].agg({'Wind Speed_km/h':'count'})
# Out:
# Wind Speed_km/h    474
# dtype: int64

# %%
wt.rename(columns={'Weather':'Weather Condition'},inplace=False)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
wt
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
wt['Visibility_km'].mean()
# Out:
# 27.66444672131151

# %%
wt['Visibility_km'].mean().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/gg/rkgw68311276r9cdpgzyzhlh0000gn/T/ipykernel_45695/752006879.py in <module>
# ----> 1 wt['Visibility_km'].mean().plot(kind='bar')
#
# AttributeError: 'float' object has no attribute 'plot'

# %%
wt['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %%
wt['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %%
wt[(wt['Weather']=='Snow')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
wt[(wt['Weather']=='Snow')].count().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
wt['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# # .str.contains() is use to find  one or more than string and when we have series of string in many columns and we have to find one or more string present in a series of column.

# %%
wt[wt['Weather'].str.contains('Snow')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
wt[(wt['Wind Speed_km/h']>=24) & (wt['Visibility_km']==25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8754  12/30/2012 18:00   -12.6             -16.0         76               24
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %%
wt.groupby('Weather').mean()
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# # agg function is use to find series of operation on given column or series of column.

# %%
wt.groupby('Weather Condition').agg({max,min})
# Out:
#                                                 Date/Time                    \
#                                                       max               min
# Weather Condition
# Clear                                       9/9/2012 5:00    1/11/2012 1:00
# Cloudy                                     9/9/2012 23:00    1/1/2012 17:00
# Drizzle                                    9/30/2012 3:00   1/23/2012 21:00
# Drizzle,Fog                                9/30/2012 2:00   1/23/2012 20:00
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00   12/17/2012 9:00
# Drizzle,Snow                             12/19/2012 18:00  12/17/2012 15:00
# Drizzle,Snow,Fog                          12/22/2012 3:00  12/18/2012 21:00
# Fog                                        9/22/2012 0:00     1/1/2012 0:00
# Freezing Drizzle                            2/1/2012 5:00   1/13/2012 10:00
# Freezing Drizzle,Fog                      12/10/2012 5:00     1/1/2012 2:00
# ...

# %%
wt[(wt['Weather']=='Fog')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
wt[(wt['Weather']=='Clear') & (wt['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 351    1/15/2012 15:00   -15.4             -22.8         53               24
# 352    1/15/2012 16:00   -15.1             -22.8         52               24
# 425    1/18/2012 17:00   -11.3             -18.8         54               26
# 440     1/19/2012 8:00   -13.7             -18.4         68               19
# 441     1/19/2012 9:00   -12.7             -17.2         69               17
# ...                ...     ...               ...        ...              ...
# 8384   12/15/2012 8:00   -10.7             -15.6         67               13
# 8385   12/15/2012 9:00   -10.4             -15.9         64               19
# 8389  12/15/2012 13:00    -8.4             -14.7         60               19
# 8631  12/25/2012 15:00    -7.1             -13.7         59               17
# 8632  12/25/2012 16:00    -7.5             -13.9         60               11
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
wt[(wt['Weather']=='Clear') & (wt['Visibility_km']>50) | (wt['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8748  12/30/2012 12:00   -12.2             -15.7         75               26
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
#
# ...

# %%
wt[(wt['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8748  12/30/2012 12:00   -12.2             -15.7         75               26
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
#
# ...

# %%
wt[wt['Weather'].isin(['Clear','Cloudy'])]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 17     1/1/2012 17:00     3.0               0.0         81               13
# 20     1/1/2012 20:00     3.2               1.3         87               19
# 21     1/1/2012 21:00     4.0               1.7         85               20
# 23     1/1/2012 23:00     5.3               2.0         79               30
# 25      1/2/2012 1:00     4.6               0.0         72               39
# ...               ...     ...               ...        ...              ...
# 8761  12/31/2012 1:00   -10.7             -14.0         77               15
# 8762  12/31/2012 2:00   -10.1             -13.4         77                9
# 8764  12/31/2012 4:00   -10.5             -12.8         83               11
# 8765  12/31/2012 5:00   -10.2             -12.4         84                6
# 8766  12/31/2012 6:00    -9.7             -11.7         85                4
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
wt[wt['Weather'].str.contains('Cloudy','Snow')]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 16     1/1/2012 16:00     2.6              -0.2         82               13
# 17     1/1/2012 17:00     3.0               0.0         81               13
# 20     1/1/2012 20:00     3.2               1.3         87               19
# 21     1/1/2012 21:00     4.0               1.7         85               20
# 23     1/1/2012 23:00     5.3               2.0         79               30
# ...               ...     ...               ...        ...              ...
# 8762  12/31/2012 2:00   -10.1             -13.4         77                9
# 8763  12/31/2012 3:00   -11.8             -14.4         81                6
# 8764  12/31/2012 4:00   -10.5             -12.8         83               11
# 8765  12/31/2012 5:00   -10.2             -12.4         84                6
# 8766  12/31/2012 6:00    -9.7             -11.7         85                4
#
#       Visibility_km  Press_kPa        Weather
# ...

# %%
wt
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...
